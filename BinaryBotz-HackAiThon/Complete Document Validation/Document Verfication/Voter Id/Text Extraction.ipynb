# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
from paddleocr import PaddleOCR, draw_ocr
from PIL import Image, ImageDraw, ImageFont

# %%
# Load the image
image_path = "VoterId_Back_2.jpg"
image = cv2.imread(image_path)

# Display the raw image
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.title('Raw Image')
plt.show()

# %%
# Initialize PaddleOCR (CPU mode)
ocr = PaddleOCR(use_angle_cls=True, lang="en")  # Change "en" if needed

# Run OCR
result = ocr.ocr(image, cls=True)

# Print extracted text with confidence scores
print("Extracted Text:")
for line in result:
    for word_info in line:
        text = word_info[1][0]  # Extract detected text
        confidence = word_info[1][1]  # Confidence score
        print(f"Detected Text: {text}, Confidence: {confidence}")
# Out:
# [2025/02/18 15:53:48] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, use_mlu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='C:\\Users\\LogaSanjeev/.paddleocr/whl\\det\\en\\en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='C:\\Users\\LogaSanjeev/.paddleocr/whl\\rec\\en\\en_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='c:\\Users\\LogaSanjeev\\anaconda3\\envs\\base-py\\Lib\\site-packages\\paddleocr\\ppocr\\utils\\en_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=True, cls_model_dir='C:\\Users\\LogaSanjeev/.paddleocr/whl\\cls\\ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, return_word_box=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, formula_algorithm='LaTeXOCR', formula_model_dir=None, formula_char_dict_path=None, formula_batch_num=1, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, formula=False, ocr=True, recovery=False, recovery_to_markdown=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='en', det=True, rec=True, type='ocr', savefile=False, ocr_version='PP-OCRv4', structure_version='PP-StructureV2')
# [2025/02/18 15:53:51] ppocr DEBUG: dt_boxes num : 55, elapsed : 0.6056559085845947
# [2025/02/18 15:53:51] ppocr DEBUG: cls num  : 55, elapsed : 0.26526713371276855
# [2025/02/18 15:53:53] ppocr DEBUG: rec_res num  : 55, elapsed : 1.94010329246521
# Extracted Text:
# Detected Text: MPD3636164, Confidence: 0.9508023262023926
# Detected Text: 4.g., Confidence: 0.7914177179336548
# Detected Text: ER, Confidence: 0.7399791479110718
# Detected Text: /, Confidence: 0.630660355091095
# Detected Text: ELECHION COMMISSION OF INDIA, Confidence: 0.924616813659668
# Detected Text: Fyer, Confidence: 0.5227382183074951
# Detected Text: 6, Confidence: 0.5236693620681763
# Detected Text: MPO3636164, Confidence: 0.9185863733291626
# Detected Text: Address, Confidence: 0.9950310587882996
# Detected Text: H.No., Confidence: 0.9657348394393921
# Detected Text: 43, Confidence: 0.9972431659698486
# Detected Text: IDENTITY CARD, Confidence: 0.928982138633728
# Detected Text: Strt/Mohalla Belagadi, Confidence: 0.9176543354988098
# Detected Text: VillTownDareedecha, Confidence: 0.8930232524871826
# Detected Text: PoliceStn., Confidence: 0.9507433176040649
# Detected Text: Disu., Confidence: 0.891994297504425
# Detected Text: Basti, Confidence: 0.9740045666694641
# Detected Text: Pin, Confidence: 0.9979082942008972
# Detected Text: 152, Confidence: 0.9699268937110901
# Detected Text: Facsimile Signature of, Confidence: 0.9636001586914062
# Detected Text: Electoral Registration Officer, Confidence: 0.9366495609283447
# Detected Text: Elector's Name, Confidence: 0.9628226161003113
# Detected Text: Amit Kumar, Confidence: 0.9624860882759094
# Detected Text: for 152-Basti, Confidence: 0.9210315346717834
# Detected Text: Ras, Confidence: 0.5767261981964111
# Detected Text: Date, Confidence: 0.9879727363586426
# Detected Text: 12-03-2007, Confidence: 0.9767956733703613
# Detected Text: Father's Name, Confidence: 0.9350011348724365
# Detected Text: Ram Lal, Confidence: 0.9012762904167175
# Detected Text: Place:Basti, Confidence: 0.9366517663002014
# Detected Text: Sx, Confidence: 0.8692263960838318
# Detected Text:  Male, Confidence: 0.8892654180526733
# Detected Text: 1.1.2007, Confidence: 0.9582803249359131
# Detected Text: 24, Confidence: 0.9575668573379517
# Detected Text: This card can be used as an Identity Card, Confidence: 0.9590523838996887
# Detected Text: Agc as on L1.2007, Confidence: 0.865432858467102
# Detected Text: under different Government Programmes., Confidence: 0.9183371663093567
# Detected Text: 126/658, Confidence: 0.9952067732810974

# %%
# Convert to PIL Image for easier text rendering
image_pil = Image.fromarray(image)
draw = ImageDraw.Draw(image_pil)

# Choose a bold font (Ensure you have a valid font file)
font_path = r"C:\Windows\Fonts\arialbd.ttf"  # Change to a bold font
try:
    font = ImageFont.truetype(font_path, 20)  # Increase font size
except IOError:
    print("Font file not found, using default font.")
    font = ImageFont.load_default()

# Draw bounding boxes and text with enhancements
for line in result:
    for word_info in line:
        box = word_info[0]  # Bounding box points (4 points)
        text = word_info[1][0]  # Extracted text
        
        # Scale the coordinates back down if OCR was run on upscaled image
        scale_x = image.shape[1] / image.shape[1]
        scale_y = image.shape[0] / image.shape[0]
        
        # Rescale bounding box coordinates to match original image
        box = [(int(point[0] * scale_x), int(point[1] * scale_y)) for point in box]

        # Draw a thicker bounding box
        draw.line(box + [box[0]], fill="red", width=4)  # Close the shape

        # Define text position
        text_x, text_y = box[0][0], box[0][1] - 30
        text_padding = 10

        # Get text bounding box for better positioning
        bbox = draw.textbbox((text_x, text_y), text, font=font)
        rect_x1, rect_y1, rect_x2, rect_y2 = (
            bbox[0] - text_padding, bbox[1] - text_padding,
            bbox[2] + text_padding, bbox[3] + text_padding
        )

        # Draw background rectangle for text
        draw.rectangle([rect_x1, rect_y1, rect_x2, rect_y2], fill="black")

        # Draw the text in lime green
        draw.text((text_x, text_y), text, fill="lime", font=font)

# Convert back to NumPy array
image_np = np.array(image_pil)

# Display the image with bounding boxes and text inline
plt.figure(figsize=(10, 10))
plt.imshow(image_np)
plt.axis("off")  # Hide axis
plt.show()

# %%
# Run Tesseract OCR on the processed image
custom_config = r'--oem 3 --psm 6'  # Engine mode 3 (Default), Page Segmentation 6 (Block of Text)
text = pytesseract.image_to_string(binary, config=custom_config)

# Print detected text
print("Detected Text:\n", text)
# Out:
# Detected Text:
#  Address } A/24,Road-1,Sanjay Gandhi
# Nagar,Hanuman Nagar,Kankarbagh,
# Town/vill - Patna,
# Anchal - Patna Sadar,
# Distt - Patna - 800020
# Gt U/ Re ATS 8, Aa MN A EPA
# aet/mta - WA,
# sae - Te Ua, ~
# Cf ee00k .
# Fabsimilé Signature of oi;
# Electoral Registration Officer No]
# 489,PATNA (CENTRAL) Constituency Bl |
# 268, Vea (Aat4) abe oa s°
# Place : Danapur Date :12/02/2005 1
# WI :erT Fete 122/02 / ook ||
# This Card may be used as en Identity Card :
# under different Government Schemes. |
# cava a falta HEE aA SRM 1
# Creed aH AT AT ST AAT |
